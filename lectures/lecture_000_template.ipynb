# %% [markdown]
# # 👨‍🏫 Lecture 3: Bellman Euquations & Dynamic Programming

# %% [markdown]
# - **Key Ideas:** The transition function $S^M$ captures the system's dynamics and discribes its temporal evoltion from one state to the next.
#
# - **Representative Formula:** $S_{t+1} = S^M(S_t, x_t, W_{t+1})$
#
# - **Python Class:** `DynamicSystem` — Simulates state transitions under stochastic noise.
#
# - **Powell's Book Reference:** Ch. 1–2
#
# - **Powell's Modeling Process Reference:** Step 3: The mathematical model - Transition function

# %% [markdown]
# # 🧭 Context

# %% [markdown]
# **Defintions**
# - Dolor sit

# %% [markdown]
# **Mathematical Formulations**
# - Dolor sit

# %% [markdown]
# **Conclusions**
# - Dolor sit

# %% [markdown]
# # 🐍 Implementation `PythonClass`

# %% [markdown]
# # 🧪 Example 3.1: t.b.d.

# %% [markdown]
# ### 📝 Definition

# %% [markdown]
# **Lorem Ipsum**
# - Dolor sit

# %% [markdown]
# ### 🚀 Execution

# %% [markdown]
# **Lorem Ipsum**
# - Dolor sit

# %% [markdown]
# ### 🎙️ Discussion

# %% [markdown]
# **Lorem Ipsum**
# - Dolor sit

# %% [markdown]
# # 🤖 What-If-Analysis

# %% [markdown]
# **Experiment B: What-if we increase the complexity of the problem?**

# %% [markdown]
# **Experiment A: What-if we ...**
#
# - Manipulation
#
# - Results
#
# - Discussion

# %% [markdown]
# # ✏️ Takeaways

# %% [markdown]
# - List 3 ***insights*** accquired in this exercise
#
# - List 3 ***skill*** accquired in this exercise
#
# - Provide ***outlook*** to bride to what comes next

# %% [markdown]
# # 🛠️ Notes

# %% [markdown]
# - TODO: Provide definition of problem complexity

# %% [markdown]
# # 🧱 Bricks

# %% [markdown]
# # 📚 Reads

# %% [markdown]
# - (Bellman) https://www.rand.org/content/dam/rand/pubs/papers/2008/P550.pdf
